# %%
import pandas as pd

# %%
sample = pd.read_csv('manual-checkup-sample.csv')

# %%
sample.head()
# Out:
#                                       title_gathered  \
# 0                              Ham And Cheese Strata
# 1  Roasted Tomatoes And Mushrooms With Herbed Ric...
# 2               Grandpa Higginbottom'S Popcorn Balls
# 3                               Best Baked Spaghetti
# 4                       Parmesan Walnut Honey Crisps
#
#                                 ingredients_gathered  \
# 0  ['2 tablespoons butter, softened', '3 tablespo...
# 1  ['3 egg tomatoes (or Roma halved lengthways)',...
# 2  ['1/4 cup vinegar', '1/4 cup water', '2 cups s...
# 3  ['1 (16 ounce) package spaghetti', '1 lb groun...
# 4  ['4 ounces parmigiano-reggiano cheese', '1/2 c...
#
#                                  directions_gathered  \
# 0  ['Generously smear a 9x13x2 baking dish with s...
# 1  ['Preheat oven to 150C (fan forced).', 'Line 2...
# 2  ['Mix vinegar, water and sugar in a large sauc...
# 3  ['Cook spaghetti according to package directio...
# ...

# %%
for i, row in sample.iterrows():
    print('------------------------')
    print('ID', i)
    print('LINK:', row.link)
    print('Gathered')
    print(row.ingredients_gathered)
    print('Fractions:',row.fractions_count_gathered)
    print('Instructions:',row.directions_count_gathered)
    print(row.directions_gathered)
    print('Recipes1M+')
    print(row.ingredients_rec1M)
    print('Fractions:',row.fractions_count_rec1M)
    print('Instructions:',row.directions_count_rec1M)
    print(row.directions_rec1M)
# Out:
# ------------------------
# ID 0
# LINK: www.food.com/recipe/ham-and-cheese-strata-424069
# Gathered
# ['2 tablespoons butter, softened', '3 tablespoons all-purpose flour', '1 tablespoon mustard powder', '1/2 teaspoon cayenne pepper (optional)', '3 cups cooked ham, cubed', '8 ounces cheddar cheese, cubed', '3 cups French bread, cubed', '4 eggs, beaten', '3 cups milk', '1 dash hot pepper sauce', '3 tablespoons butter, melted', '1/2 cup freshly grated parmesan cheese']
# Fractions: 2
# Instructions: 5
# ...
